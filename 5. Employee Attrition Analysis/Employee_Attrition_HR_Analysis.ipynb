# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;">Problem Statement
#
# Employee Attrition has always been a crucial concern for a company. Attrition means a loss to the company in terms of cost invested in training an employee. There are a few companies which were forced to close due to high level of attrition. To minimize attrition several companies tries to analyze and understand several factors which migh lead to an employee to leave the company.
# The IBM HR Attrition Case Study is a dataset which aims to identify important factors that might be influential in determining an employee who might leave the company. You are hired by the company and your objective is to undestand the data and to identify the patterns in the data which will help HR team to take decisive actions to reduce the attrition rate.
#
# There are two given dataset, Company_Data.csv contains information of an employee related to the company and Personal_Data cotains personal information of an employee.

# %% [markdown]
# ## Data Dictionary
#
# 1. EmpId-              Employee ID
# 2. AGE-                Employee Age
# 3. EducationField-     Field of Education
# 4. Gender        -     Employee Gender
# 5. MaritalStatus -     Employee Marital Status
# 6. DistanceFromHome-   Distance from home to work (in miles)
# 7. BusinessTravel-     Frequency of business travel
# 8. Department-         Department of the employee
# 9. HourlyRate-         Hourly rate of an employee
# 10. JobLevel-          Job Level of the employee. Higher job level means senior post
# 11. JobRole-           Job Role of an employee
# 12. JobSatisfaction-   Job Satisfaction level of  an employee
# 13. MonthlyRate-       Montly rate of an employee
# 14. NumCompaniesWorked-How many companies has the employee worked before
# 15. OverTime-          Does the employee gets overtime
# 16. PercentSalaryHike- Average percentage take for the employee
# 17. TotalWorkingYears- Total Years of Experience of an employee
# 18. WorkLifeBalance-   Work life balance of an employee (4 means highly satisfied)
# 19. YearsAtCompany-    Years employee have worked in current company
# 20. YearsInCurrentRole-Years employee have worked in current role
# 21. TotalWorkingYears- Total Years of Experience of an employee
# 22. YearsSinceLastPromotion-   Number of years since last promotion
# 23. YearsWithCurrManager- Number of years with current manager
# 24. Attrition-         Employee has left the company or not

# %% [markdown]
# ### Change your Working Directory

# %%
import os

# %%
print(os.name)
# Out:
# nt

# %%
print(os.getcwd()) # Got current working directory
# Out:
# C:\Users\anime\Downloads\Great Learning\Introduction to Python\Week 1 and 2 Practice Assessment

# %%
os.listdir('.') # gives the files in the current working directory
# Out:
# ['.ipynb_checkpoints',
#  'Company_Data.csv',
#  'Personal_Data.csv',
#  'Questions_HR_Attrition.ipynb',
#  'Questions_Store_Sale.ipynb',
#  'sales.csv',
#  'Solution_Forbes_Billionaires.html',
#  'Solution_Forbes_Billionaires.pdf',
#  'Solution_HR Attrition.pdf',
#  'Solution_HR+Attrition.html',
#  'Solution_Store Sales.pdf',
#  'Solution_Store+Sales.html']

# %%
os.mkdir('C:\\Users\\anime\\Downloads\\Great Learning\\\Introduction to Python\\Week 1 and 2 Practice Assessment\\new_dir')

# %%
# Answer
os.chdir('C:\\Users\\anime\\Downloads\\Great Learning\\\Introduction to Python\\Week 1 and 2 Practice Assessment\\new_dir')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\anime\\Downloads\\Great Learning\\Introduction to Python\\Week 1 and 2 Practice Assessment\\new_dir'

# %% [markdown]
# ### Q1. Import all the necessary libraries (Numpy and Pandas)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Q2. Import both csv files (and name Company_Data as "company" and Personal_Data as "personal" )

# %% [markdown]
# Load the Data file into Python DataFrame using pandas read_csv method

# %%
company = pd.read_csv('Company_Data.csv')
personal = pd.read_csv('Personal_Data.csv')

# %% [markdown]
# ### Q3.  View Top 10 rows of both the datasets

# %% [markdown]
# Hint:Head function is used to view the top records. The number of records to be viewed, needs to be  given in the parenthesis. Default value is 5.

# %%
company.head(10)
# Out:
#      EmpID     BusinessTravel              Department  HourlyRate  JobLevel  \
# 0  2102210      Travel_Rarely                   Sales          94       2.0
# 1  2102211  Travel_Frequently  Research & Development          61       2.0
# 2  2102212      Travel_Rarely  Research & Development          92       1.0
# 3  2102213  Travel_Frequently  Research & Development          56       1.0
# 4  2102214      Travel_Rarely  Research & Development          40       1.0
# 5  2102215  Travel_Frequently  Research & Development          79       1.0
# 6  2102216      Travel_Rarely  Research & Development          81       1.0
# 7  2102217      Travel_Rarely  Research & Development          67       1.0
# 8  2102218  Travel_Frequently  Research & Development          44       3.0
# 9  2102219      Travel_Rarely  Research & Development          94       2.0
#
#                      JobRole  JobSatisfaction  MonthlyRate  \
# 0            Sales Executive                4        19479
# 1         Research Scientist                2        24907
# 2      Laboratory Technician                3         2396
# 3         Research Scientist                3        23159
# 4      Laboratory Technician                2        16632
# 5      Laboratory Technician                4        11864
# 6      Laboratory Technician                1         9964
# 7      Laboratory Technician                3        13335
# 8     Manufacturing Director                3         8787
# 9  Healthcare Representative                3        16577
#
#    NumCompaniesWorked OverTime  PercentSalaryHike  TotalWorkingYears  \
# 0                   8      Yes                 11                  8
# 1                   1       No                 23                 10
# 2                   6      Yes                 15                  7
# 3                   1      Yes                 11                  8
# 4                   9       No                 12                  6
# 5                   0       No                 13                  8
# 6                   4      Yes                 20                 12
# 7                   1       No                 22                  1
# 8                   0       No                 21                 10
# 9                   6       No                 13                 17
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0              1.0               6                   4
# 1              3.0              10                   7
# 2              3.0               0                   0
# 3              3.0               8                   7
# 4              3.0               2                   2
# 5              2.0               7                   7
# 6              2.0               1                   0
# 7              3.0               1                   0
# 8              3.0               9                   7
# 9              2.0               7                   7
#
#    YearsSinceLastPromotion  YearsWithCurrManager Attrition
# 0                        0                     5       Yes
# 1                        1                     7        No
# 2                        0                     0       Yes
# 3                        3                     0        No
# 4                        2                     2        No
# 5                        3                     6        No
# 6                        0                     0        No
# 7                        0                     0        No
# 8                        1                     8        No
# 9                        7                     7        No

# %%
personal.head(10)
# Out:
#      EmpID  Age EducationField  Gender MaritalStatus  DistanceFromHome
# 0  2102210   41  Life Sciences  Female        Single                 1
# 1  2102211   49  Life Sciences    Male       Married                 8
# 2  2102212   37          Other    Male        Single                 2
# 3  2102213   33  Life Sciences  Female       Married                 3
# 4  2102214   27        Medical    Male       Married                 2
# 5  2102215   32  Life Sciences    Male        Single                 2
# 6  2102216   59        Medical  Female       Married                 3
# 7  2102217   30  Life Sciences    Male      Divorced                24
# 8  2102218   38  Life Sciences    Male        Single                23
# 9  2102219   36        Medical    Male       Married                27

# %% [markdown]
# ### Q4. Merge both datasets and name the merged dataset as df
#
# Hint:Merge the datasets using pd.merge() command- Use how="outer" and on="EmpID"

# %%
df = pd.merge(company,personal, how = "outer", on = "EmpID")
Laboratory Technician                3        10228
#
#       NumCompaniesWorked OverTime       ...         YearsAtCompany  \
# 0                      8      Yes       ...                      6
# 1                      1       No       ...                     10
# 2                      6      Yes       ...                      0
# 3                      1      Yes       ...                      8
# 4                      9       No       ...                      2
# 5                      0       No       ...                      7
# 6                      4      Yes       ...                      1
# 7                      1       No       ...                      1
# 8                      0       No       ...                      9
# 9                      6       No       ...                      7
# 10                     0       No       ...                      5
# 11                     0      Yes       ...                      9
# 12                     1       No       ...                      5
# 13                     0       No       ...                      2
# 14                     5      Yes       ...                      4
# 15                     1       No       ...                     10
# 16                     0      Yes       ...                      6
# 17                     1      Yes       ...                      1
# 18                     2       No       ...                     25
# 19                     5      Yes       ...                      3
# 20                     0       No       ...                      4
# 21                     7       No       ...                      5
# 22                     0       No       ...                     12
# 23                     1       No       ...                      0
# 24                     2       No       ...                      4
# 25                     4       No       ...                     14
# 26                     1      Yes       ...                     10
# 27                     0       No       ...                      9
# 28                     3       No       ...                     22
# 29                     3       No       ...                      2
# ...                  ...      ...       ...                    ...
# 1440                   7       No       ...                      4
# 1441                   1       No       ...                     13
# 1442                   9      Yes       ...                      2
# 1443                   5       No       ...                     22
# 1444                   8       No       ...                     10
# 1445                   0       No       ...                     20
# 1446                   1       No       ...                      8
# 1447                   1       No       ...                     15
# 1448                   2       No       ...                      5
# 1449                   1       No       ...                      4
# 1450                   1      Yes       ...                      9
# 1451                   1       No       ...                     10
# 1452                   7       No       ...                      6
# 1453                   4       No       ...                      6
# 1454                   8       No       ...                      5
# 1455                   2       No       ...                      2
# 1456                   1      Yes       ...                     10
# 1457                   2       No       ...                      5
# 1458                   1       No       ...                      4
# 1459                   4      Yes       ...                      4
# 1460                   1       No       ...                      5
# 1461                   4      Yes       ...                      3
# 1462                   0       No       ...                     20
# 1463                   0       No       ...                      9
# 1464                   0       No       ...                      4
# 1465                   4       No       ...                      5
# 1466                   4       No       ...                      7
# 1467                   1      Yes       ...                      6
# 1468                   2       No       ...                      9
# 1469                   2       No       ...                      4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# 5                      7                        3                     6
# 6                      0                        0                     0
# 7                      0                        0                     0
# 8                      7                        1                     8
# 9                      7                        7                     7
# 10                     4                        0                     3
# 11                     5                        0                     8
# 12                     2                        4                     3
# 13                     2                        1                     2
# 14                     2                        0                     3
# 15                     9                        8                     8
# 16                     2                        0                     5
# 17                     0                        0                     0
# 18                     8                        3                     7
# 19                     2                        1                     2
# 20                     2                        1                     3
# 21                     3                        0                     3
# 22                     6                        2                    11
# 23                     0                        0                     0
# 24                     2                        1                     3
# 25                    13                        4                     8
# 26                     2                        6                     7
# 27                     7                        4                     2
# 28                     6                        5                    17
# 29                     2                        2                     1
# ...                  ...                      ...                   ...
# 1440                   2                        0                     2
# 1441                  12                        1                     9
# 1442                   2                        2                     2
# 1443                   6                        4                    14
# 1444                   9                        9                     8
# 1445                   7                        0                    10
# 1446                   7                        1                     7
# 1447                  12                       11                    11
# 1448                   4                        0                     4
# 1449                   2                        1                     2
# 1450                   0                        1                     7
# 1451                   7                        1                     9
# 1452                   3                        0                     1
# 1453                   3                        0                     0
# 1454                   3                        0                     1
# 1455                   2                        2                     2
# 1456                   2                        0                     2
# 1457                   3                        0                     2
# 1458                   3                        1                     1
# 1459                   3                        0                     3
# 1460                   4                        0                     4
# 1461                   2                        2                     0
# 1462                   9                        9                     6
# 1463                   4                        1                     7
# 1464                   2                        0                     0
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
#       Attrition  Age    EducationField  Gender  MaritalStatus DistanceFromHome
# 0           Yes   41     Life Sciences  Female         Single                1
# 1            No   49     Life Sciences    Male        Married                8
# 2           Yes   37             Other    Male         Single                2
# 3            No   33     Life Sciences  Female        Married                3
# 4            No   27           Medical    Male        Married                2
# 5            No   32     Life Sciences    Male         Single                2
# 6            No   59           Medical  Female        Married                3
# 7            No   30     Life Sciences    Male       Divorced               24
# 8            No   38     Life Sciences    Male         Single               23
# 9            No   36           Medical    Male        Married               27
# 10           No   35           Medical    Male        Married               16
# 11           No   29     Life Sciences  Female         Single               15
# 12           No   31     Life Sciences    Male       Divorced               26
# 13           No   34           Medical    Male       Divorced               19
# 14          Yes   28     Life Sciences    Male         Single               24
# 15           No   29     Life Sciences  Female       Divorced               21
# 16           No   32     Life Sciences    Male       Divorced                5
# 17           No   22           Medical    Male       Divorced               16
# 18           No   53     Life Sciences  Female        Married                2
# 19           No   38     Life Sciences    Male         Single                2
# 20           No   24             Other  Female       Divorced               11
# 21          Yes   36     Life Sciences    Male         Single                9
# 22           No   34     Life Sciences  Female         Single                7
# 23           No   21     Life Sciences    Male         Single               15
# 24          Yes   34           Medical    Male         Single                6
# 25           No   53             Other  Female       Divorced                5
# 26          Yes   32     Life Sciences  Female         Single               16
# 27           No   42         Marketing    Male        Married                8
# 28           No   44           Medical  Female        Married                7
# 29           No   46         Marketing  Female         Single                2
# ...         ...  ...               ...     ...            ...              ...
# 1440         No   36     Life Sciences  Female       Divorced                4
# 1441         No   56     Life Sciences    Male       Divorced                1
# 1442        Yes   29           Medical    Male        Married                1
# 1443         No   42     Life Sciences    Male        Married                2
# 1444        Yes   56  Technical Degree    Male        Married                7
# 1445         No   41     Life Sciences  Female        Married               28
# 1446         No   34         Marketing  Female        Married               28
# 1447         No   36         Marketing    Male       Divorced               15
# 1448         No   41     Life Sciences    Male       Divorced                3
# 1449         No   32  Technical Degree    Male         Single                2
# 1450         No   35     Life Sciences  Female         Single               26
# 1451         No   38     Life Sciences  Female        Married               10
# 1452        Yes   50     Life Sciences    Male       Divorced                1
# 1453         No   36         Marketing  Female        Married               11
# 1454         No   45     Life Sciences  Female         Single               20
# 1455         No   40     Life Sciences    Male         Single                2
# 1456         No   35     Life Sciences    Male        Married               18
# 1457         No   40           Medical  Female        Married                2
# 1458         No   35     Life Sciences  Female        Married                1
# 1459         No   29             Other    Male        Married               13
# 1460         No   29           Medical  Female         Single               28
# 1461        Yes   50         Marketing    Male       Divorced               28
# 1462         No   39         Marketing  Female        Married               24
# 1463         No   31           Medical    Male         Single                5
# 1464         No   26             Other  Female         Single                5
# 1465         No   36           Medical    Male        Married               23
# 1466         No   39           Medical    Male        Married                6
# 1467         No   27     Life Sciences    Male        Married                4
# 1468         No   49           Medical    Male        Married                2
# 1469         No   34           Medical    Male        Married                8
#
# [1470 rows x 23 columns]

# %% [markdown]
#  ### Q5. View Last 5 records of combined dataframe "df".

# %% [markdown]
# Hint:Tail function is used to view the last records. The number of records to be viewed, needs to be given in the parenthesis.Default value is 5.

# %%
df.tail()
# Out:
#         EmpID     BusinessTravel              Department  HourlyRate  \
# 1465  2103675  Travel_Frequently  Research & Development          41
# 1466  2103676      Travel_Rarely  Research & Development          42
# 1467  2103677      Travel_Rarely  Research & Development          87
# 1468  2103678  Travel_Frequently                   Sales          63
# 1469  2103679      Travel_Rarely  Research & Development          82
#
#       JobLevel                    JobRole  JobSatisfaction  MonthlyRate  \
# 1465       2.0      Laboratory Technician                4        12290
# 1466       3.0  Healthcare Representative                1        21457
# 1467       2.0     Manufacturing Director                2         5174
# 1468       2.0            Sales Executive                2        13243
# 1469       2.0      Laboratory Technician                3        10228
#
#       NumCompaniesWorked OverTime       ...         YearsAtCompany  \
# 1465                   4       No       ...                      5
# 1466                   4       No       ...                      7
# 1467                   1      Yes       ...                      6
# 1468                   2       No       ...                      9
# 1469                   2       No       ...                      4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
#       Attrition  Age  EducationField Gender  MaritalStatus DistanceFromHome
# 1465         No   36         Medical   Male        Married               23
# 1466         No   39         Medical   Male        Married                6
# 1467         No   27   Life Sciences   Male        Married                4
# 1468         No   49         Medical   Male        Married                2
# 1469         No   34         Medical   Male        Married                8
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Q6. Display the shape/dimensions of dataset.

# %% [markdown]
# Displaying the shape of the Data Frame in which first value gives number of Rows and second value gives number of columns.
#
# Hint: Use "shape" function

# %%
# Answer
df.shape
# Out:
# (1470, 23)

# %%
print("The number of rows are: ", df.shape[0], "\nThe number of columns are: ", df.shape[1])
# Out:
# The number of rows are:  1470
# The number of columns are:  23

# %% [markdown]
# ### Q7. Check for missing values. Display number of null values per column.

# %% [markdown]
# Hint: use isnull() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1470 entries, 0 to 1469
# Data columns (total 23 columns):
# EmpID                      1470 non-null int64
# BusinessTravel             1470 non-null object
# Department                 1470 non-null object
# HourlyRate                 1470 non-null int64
# JobLevel                   1464 non-null float64
# JobRole                    1470 non-null object
# JobSatisfaction            1470 non-null int64
# MonthlyRate                1470 non-null int64
# NumCompaniesWorked         1470 non-null int64
# OverTime                   1470 non-null object
# PercentSalaryHike          1470 non-null int64
# TotalWorkingYears          1470 non-null int64
# WorkLifeBalance            1466 non-null float64
# YearsAtCompany             1470 non-null int64
# YearsInCurrentRole         1470 non-null int64
# YearsSinceLastPromotion    1470 non-null int64
# YearsWithCurrManager       1470 non-null int64
# Attrition                  1470 non-null object
# Age                        1470 non-null int64
# EducationField             1470 non-null object
# Gender                     1470 non-null object
# MaritalStatus              1470 non-null object
# DistanceFromHome           1470 non-null int64
# dtypes: float64(2), int64(13), object(8)
# memory usage: 275.6+ KB

# %%
# Answer
df.isnull().sum()
# Out:
# EmpID                      0
# BusinessTravel             0
# Department                 0
# HourlyRate                 0
# JobLevel                   6
# JobRole                    0
# JobSatisfaction            0
# MonthlyRate                0
# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# TotalWorkingYears          0
# WorkLifeBalance            4
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Attrition                  0
# Age                        0
# EducationField             0
# Gender                     0
# MaritalStatus              0
# DistanceFromHome           0
# dtype: int64

# %%
type(df.isnull().sum())
# Out:
# pandas.core.series.Series

# %% [markdown]
# There are missing values present in the "Joblevel" and "WorklifeBalance" variables of the dataset.

# %% [markdown]
# ### Q8.  Drop null values from "df" and check if there are any missing value left after dropping null values

# %%
df.dropna(inplace = True)
df
# Out:
#         EmpID     BusinessTravel              Department  HourlyRate  \
# 0     2102210      Travel_Rarely                   Sales          94
# 1     2102211  Travel_Frequently  Research & Development          61
# 2     2102212      Travel_Rarely  Research & Development          92
# 3     2102213  Travel_Frequently  Research & Development          56
# 4     2102214      Travel_Rarely  Research & Development          40
# 5     2102215  Travel_Frequently  Research & Development          79
# 6     2102216      Travel_Rarely  Research & Development          81
# 7     2102217      Travel_Rarely  Research & Development          67
# 8     2102218  Travel_Frequently  Research & Development          44
# 9     2102219      Travel_Rarely  Research & Development          94
# 10    2102220      Travel_Rarely  Research & Development          84
# 15    2102225      Travel_Rarely  Research & Development          51
# 16    2102226      Travel_Rarely  Research & Development          80
# 17    2102227         Non-Travel  Research & Development          96
# 18    2102228      Travel_Rarely                   Sales          78
# 19    2102229      Travel_Rarely  Research & Development          45
# 20    2102230         Non-Travel  Research & Development          96
# 21    2102231      Travel_Rarely                   Sales          82
# 22    2102232      Travel_Rarely  Research & Development          53
# 23    2102233      Travel_Rarely  Research & Development          96
# 24    2102234      Travel_Rarely  Research & Development          83
# 25    2102235      Travel_Rarely  Research & Development          58
# 26    2102236  Travel_Frequently  Research & Development          72
# 27    2102237      Travel_Rarely                   Sales          48
# 28    2102238      Travel_Rarely  Research & Development          42
# 29    2102239      Travel_Rarely                   Sales          83
# 30    2102240      Travel_Rarely  Research & Development          78
# 31    2102241      Travel_Rarely  Research & Development          41
# 32    2102242      Travel_Rarely  Research & Development          83
# 33    2102243      Travel_Rarely                   Sales          56
# ...       ...                ...                     ...         ...
# 1440  2103650  Travel_Frequently  Research & Development          97
# 1441  2103651         Non-Travel  Research & Development          57
# 1442  2103652      Travel_Rarely  Research & Development          36
# 1443  2103653      Travel_Rarely  Research & Development          56
# 1444  2103654      Travel_Rarely  Research & Development          72
# 1445  2103655      Travel_Rarely  Research & Development          60
# 1446  2103656      Travel_Rarely                   Sales          95
# 1447  2103657         Non-Travel                   Sales          88
# 1448  2103658      Travel_Rarely                   Sales          57
# 1449  2103659      Travel_Rarely  Research & Development          78
# 1450  2103660      Travel_Rarely         Human Resources          31
# 1451  2103661      Travel_Rarely                   Sales         100
# 1452  2103662  Travel_Frequently                   Sales          94
# 1453  2103663      Travel_Rarely                   Sales         100
# 1454  2103664      Travel_Rarely                   Sales          50
# 1455  2103665      Travel_Rarely  Research & Development          52
# 1456  2103666  Travel_Frequently  Research & Development          80
# 1457  2103667      Travel_Rarely  Research & Development          98
# 1458  2103668      Travel_Rarely  Research & Development          62
# 1459  2103669      Travel_Rarely  Research & Development          46
# 1460  2103670      Travel_Rarely  Research & Development          73
# 1461  2103671      Travel_Rarely                   Sales          39
# 1462  2103672      Travel_Rarely                   Sales          60
# 1463  2103673         Non-Travel  Research & Development          74
# 1464  2103674      Travel_Rarely                   Sales          30
# 1465  2103675  Travel_Frequently  Research & Development          41
# 1466  2103676      Travel_Rarely  Research & Development          42
# 4                      9       No       ...                      2
# 5                      0       No       ...                      7
# 6                      4      Yes       ...                      1
# 7                      1       No       ...                      1
# 8                      0       No       ...                      9
# 9                      6       No       ...                      7
# 10                     0       No       ...                      5
# 15                     1       No       ...                     10
# 16                     0      Yes       ...                      6
# 17                     1      Yes       ...                      1
# 18                     2       No       ...                     25
# 19                     5      Yes       ...                      3
# 20                     0       No       ...                      4
# 21                     7       No       ...                      5
# 22                     0       No       ...                     12
# 23                     1       No       ...                      0
# 24                     2       No       ...                      4
# 25                     4       No       ...                     14
# 26                     1      Yes       ...                     10
# 27                     0       No       ...                      9
# 28                     3       No       ...                     22
# 29                     3       No       ...                      2
# 30                     4       No       ...                      1
# 31                     2      Yes       ...                      4
# 32                     1       No       ...                     10
# 33                     3       No       ...                      1
# ...                  ...      ...       ...                    ...
# 1440                   7       No       ...                      4
# 1441                   1       No       ...                     13
# 1442                   9      Yes       ...                      2
# 1443                   5       No       ...                     22
# 1444                   8       No       ...                     10
# 1445                   0       No       ...                     20
# 1446                   1       No       ...                      8
# 1447                   1       No       ...                     15
# 1448                   2       No       ...                      5
# 1449                   1       No       ...                      4
# 1450                   1      Yes       ...                      9
# 1451                   1       No       ...                     10
# 1452                   7       No       ...                      6
# 1453                   4       No       ...                      6
# 1454                   8       No       ...                      5
# 1455                   2       No       ...                      2
# 1456                   1      Yes       ...                     10
# 1457                   2       No       ...                      5
# 1458                   1       No       ...                      4
# 1459                   4      Yes       ...                      4
# 1460                   1       No       ...                      5
# 1461                   4      Yes       ...                      3
# 1462                   0       No       ...                     20
# 1463                   0       No       ...                      9
# 1464                   0       No       ...                      4
# 1465                   4       No       ...                      5
# 1466                   4       No       ...                      7
# 1467                   1      Yes       ...                      6
# 1468                   2       No       ...                      9
# 1469                   2       No       ...                      4
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                      4                        0                     5
# 1                      7                        1                     7
# 2                      0                        0                     0
# 3                      7                        3                     0
# 4                      2                        2                     2
# 5                      7                        3                     6
# 6                      0                        0                     0
# 7                      0                        0                     0
# 8                      7                        1                     8
# 9                      7                        7                     7
# 10                     4                        0                     3
# 15                     9                        8                     8
# 16                     2                        0                     5
# 17                     0                        0                     0
# 18                     8                        3                     7
# 19                     2                        1                     2
# 20                     2                        1                     3
# 21                     3                        0                     3
# 22                     6                        2                    11
# 23                     0                        0                     0
# 24                     2                        1                     3
# 25                    13                        4                     8
# 26                     2                        6                     7
# 27                     7                        4                     2
# 28                     6                        5                    17
# 29                     2                        2                     1
# 30                     1                        0                     0
# 31                     2                        1                     3
# 32                     0                        1                     8
# 33                     0                        0                     0
# ...                  ...                      ...                   ...
# 1440                   2                        0                     2
# 1441                  12                        1                     9
# 1442                   2                        2                     2
# 1443                   6                        4                    14
# 1444                   9                        9                     8
# 1445                   7                        0                    10
# 1446                   7                        1                     7
# 1447                  12                       11                    11
# 1448                   4                        0                     4
# 1449                   2                        1                     2
# 1450                   0                        1                     7
# 1451                   7                        1                     9
# 1452                   3                        0                     1
# 1453                   3                        0                     0
# 1454                   3                        0                     1
# 1455                   2                        2                     2
# 1456                   2                        0                     2
# 1457                   3                        0                     2
# 1458                   3                        1                     1
# 1459                   3                        0                     3
# 1460                   4                        0                     4
# 1461                   2                        2                     0
# 1462                   9                        9                     6
# 1463                   4                        1                     7
# 1464                   2                        0                     0
# 1465                   2                        0                     3
# 1466                   7                        1                     7
# 1467                   2                        0                     3
# 1468                   6                        0                     8
# 1469                   3                        1                     2
#
#

# NumCompaniesWorked         0
# OverTime                   0
# PercentSalaryHike          0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Attrition                  0
# Age                        0
# EducationField             0
# Gender                     0
# MaritalStatus              0
# DistanceFromHome           0
# dtype: int64

# %% [markdown]
# ### Q9. Check the datatype, number of non negative values and name of each variable in the dataset.
#
# Hint : Use info() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1469
# Data columns (total 23 columns):
# EmpID                      1460 non-null int64
# BusinessTravel             1460 non-null object
# Department                 1460 non-null object
# HourlyRate                 1460 non-null int64
# JobLevel                   1460 non-null float64
# JobRole                    1460 non-null object
# JobSatisfaction            1460 non-null int64
# MonthlyRate                1460 non-null int64
# NumCompaniesWorked         1460 non-null int64
# OverTime                   1460 non-null object
# PercentSalaryHike          1460 non-null int64
# TotalWorkingYears          1460 non-null int64
# WorkLifeBalance            1460 non-null float64
# YearsAtCompany             1460 non-null int64
# YearsInCurrentRole         1460 non-null int64
# YearsSinceLastPromotion    1460 non-null int64
# YearsWithCurrManager       1460 non-null int64
# Attrition                  1460 non-null object
# Age                        1460 non-null int64
# EducationField             1460 non-null object
# Gender                     1460 non-null object
# MaritalStatus              1460 non-null object
# DistanceFromHome           1460 non-null int64
# dtypes: float64(2), int64(13), object(8)
# memory usage: 273.8+ KB

# %% [markdown]
# ### Q10. Check the summary of the dataset
# Hint: To see the summary of a dataframe we will use describe function.

# %%
df.describe(include = "all") # include="all" will give summary of all the categorical and numerical variables
# Out:
#                EmpID BusinessTravel              Department   HourlyRate  \
# count   1.460000e+03           1460                    1460  1460.000000
# unique           NaN              3                       3          NaN
# top              NaN  Travel_Rarely  Research & Development          NaN
# freq             NaN           1036                     952          NaN
# mean    2.102949e+06            NaN                     NaN    65.914384
# std     4.220800e+02            NaN                     NaN    20.316655
# min     2.102210e+06            NaN                     NaN    30.000000
# 25%     2.102585e+06            NaN                     NaN    48.000000
# 50%     2.102950e+06            NaN                     NaN    66.000000
# 75%     2.103314e+06            NaN                     NaN    84.000000
# max     2.103679e+06            NaN                     NaN   100.000000
#
#            JobLevel          JobRole  JobSatisfaction   MonthlyRate  \
# count   1460.000000             1460      1460.000000   1460.000000
# unique          NaN                9              NaN           NaN
# top             NaN  Sales Executive              NaN           NaN
# freq            NaN              325              NaN           NaN
# mean       2.065753              NaN         2.729452  14299.465068
# std        1.107544              NaN         1.103963   7123.418042
# min        1.000000              NaN         1.000000   2094.000000
# 25%        1.000000              NaN         2.000000   8039.750000
# 50%        2.000000              NaN         3.000000  14225.500000
# 75%        3.000000              NaN         4.000000  20460.500000
# max        5.000000              NaN         4.000000  26999.000000
#
#         NumCompaniesWorked OverTime       ...         YearsAtCompany  \
# count          1460.000000     1460       ...            1460.000000
# unique                 NaN        2       ...                    NaN
# top                    NaN       No       ...                    NaN
# freq                   NaN     1048       ...                    NaN
# mean              2.696575      NaN       ...               7.028767
# std               2.499154      NaN       ...               6.139390
# min               0.000000      NaN       ...               0.000000
# 25%               1.000000      NaN       ...               3.000000
# 50%               2.000000      NaN       ...               5.000000
# 75%               4.000000      NaN       ...              10.000000
# max               9.000000      NaN       ...              40.000000
#
#         YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# count          1460.000000              1460.000000           1460.000000
# unique                 NaN                      NaN                   NaN
# top                    NaN                      NaN                   NaN
# freq                   NaN                      NaN                   NaN
# mean              4.243836                 2.197945              4.133562
# std               3.628309                 3.229596              3.573852
# min               0.000000                 0.000000              0.000000
# 25%               2.000000                 0.000000              2.000000
# 50%               3.000000                 1.000000              3.000000
# 75%               7.000000                 3.000000              7.000000
# max              18.000000                15.000000             17.000000
#
#         Attrition          Age  EducationField Gender  MaritalStatus  \
# count        1460  1460.000000            1460   1460           1460
# unique          2          NaN               6      2              3
# top            No          NaN   Life Sciences   Male        Married
# freq         1225          NaN             600    875            671
# mean          NaN    36.910959             NaN    NaN            NaN
# std           NaN     9.126498             NaN    NaN            NaN
# min           NaN    18.000000             NaN    NaN            NaN
# 25%           NaN    30.000000             NaN    NaN            NaN
# 50%           NaN    36.000000             NaN    NaN            NaN
# 75%           NaN    43.000000             NaN    NaN            NaN
# max           NaN    60.000000             NaN    NaN            NaN
#
#        DistanceFromHome
# count       1460.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           9.172603
# std            8.101841
# min            1.000000
# 25%            2.000000
# 50%            7.000000
# 75%           14.000000
# max           29.000000
#
# [11 rows x 23 columns]

# %% [markdown]
# ### Q11. Drop  the variable EmpID from the dataframe df.
# To drop any variable, use drop() function.

# %%
df.drop("EmpID", axis =1, inplace = True)

# %%
df.head()
# Out:
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0        Sales Executive                4        19479                   8
# 1     Research Scientist                2        24907                   1
# 2  Laboratory Technician                3         2396                   6
# 3     Research Scientist                3        23159                   1
# 4  Laboratory Technician                2        16632                   9
#
#   OverTime  PercentSalaryHike       ...         YearsAtCompany  \
# 0      Yes                 11       ...                      6
# 1       No                 23       ...                     10
# 2      Yes                 15       ...                      0
# 3      Yes                 11       ...                      8
# 4       No                 12       ...                      2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
#    Attrition  Age EducationField  Gender MaritalStatus DistanceFromHome
# 0        Yes   41  Life Sciences  Female        Single                1
# 1         No   49  Life Sciences    Male       Married                8
# 2        Yes   37          Other    Male        Single                2
# 3         No   33  Life Sciences  Female       Married                3
# 4         No   27        Medical    Male       Married                2
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q12. Check how many employees left the company from the given dataset
# Hint :Use value_counts() function

# %%
df["Attrition"].value_counts()
# Out:
# No     1225
# Yes     235
# Name: Attrition, dtype: int64

# %%
# or
df.Attrition.value_counts()
# Out:
# No     1225
# Yes     235
# Name: Attrition, dtype: int64

# %% [markdown]
# In the given dataset, 235 employees left the company.

# %%
df.Attrition.value_counts(normalize=True)
# normalize=True gives the output in the ratio terms
# Out:
# No     0.839041
# Yes    0.160959
# Name: Attrition, dtype: float64

# %% [markdown]
# In the given dataset, 16.09% of the employees left the company.

# %% [markdown]
# ### Q13. Create a subset "df_new" from the dataset "df" which contain data of all the employees who have attrited. Also check the shape of the new dataset

# %%
df_new = df[df["Attrition"] == "Yes"]
df_new.head()
# Out:
#        BusinessTravel              Department  HourlyRate  JobLevel  \
# 0       Travel_Rarely                   Sales          94       2.0
# 2       Travel_Rarely  Research & Development          92       1.0
# 21      Travel_Rarely                   Sales          82       1.0
# 24      Travel_Rarely  Research & Development          83       1.0
# 26  Travel_Frequently  Research & Development          72       1.0
#
#                   JobRole  JobSatisfaction  MonthlyRate  NumCompaniesWorked  \
# 0         Sales Executive                4        19479                   8
# 2   Laboratory Technician                3         2396                   6
# 21   Sales Representative                1         6986                   7
# 24     Research Scientist                1        17102                   2
# 26     Research Scientist                1         4681                   1
#
#    OverTime  PercentSalaryHike       ...         YearsAtCompany  \
# 0       Yes                 11       ...                      6
# 2       Yes                 15       ...                      0
# 21       No                 23       ...                      5
# 24       No                 11       ...                      4
# 26      Yes                 22       ...                     10
#
#     YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                    4                        0                     5
# 2                    0                        0                     0
# 21                   3                        0                     3
# 24                   2                        1                     3
# 26                   2                        6                     7
#
#     Attrition  Age EducationField  Gender MaritalStatus DistanceFromHome
# 0         Yes   41  Life Sciences  Female        Single                1
# 2         Yes   37          Other    Male        Single                2
# 21        Yes   36  Life Sciences    Male        Single                9
# 24        Yes   34        Medical    Male        Single                6
# 26        Yes   32  Life Sciences  Female        Single               16
#
# [5 rows x 22 columns]

# %%
df_new.shape
# Out:
# (235, 22)

# %% [markdown]
# ### Q14. Create the top 5 rows and first 5 columns in a matrix format. Use
#
# ---
#
# dataframe "df"
#
# Hint- use iloc function

# %%
df.iloc[:5,:5]
# Out:
#       BusinessTravel              Department  HourlyRate  JobLevel  \
# 0      Travel_Rarely                   Sales          94       2.0
# 1  Travel_Frequently  Research & Development          61       2.0
# 2      Travel_Rarely  Research & Development          92       1.0
# 3  Travel_Frequently  Research & Development          56       1.0
# 4      Travel_Rarely  Research & Development          40       1.0
#
#                  JobRole
# 0        Sales Executive
# 1     Research Scientist
# 2  Laboratory Technician
# 3     Research Scientist
# 4  Laboratory Technician

# %% [markdown]
# ### Q15.  Analyze the mean for all the variables for employees who have attrited and whose who have not.
#
# Hint: Use groupby() function

# %%
df.groupby(["Attrition"]).mean()
# Out:
#            HourlyRate  JobLevel  JobSatisfaction   MonthlyRate  \
# Attrition
# No          65.977959  2.146939         2.780408  14254.193469
# Yes         65.582979  1.642553         2.463830  14535.455319
#
#            NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# Attrition
# No                   2.648980          15.242449          11.862857
# Yes                  2.944681          15.093617           8.280851
#
#            WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Attrition
# No                2.782041        7.388571            4.497959
# Yes               2.659574        5.153191            2.919149
#
#            YearsSinceLastPromotion  YearsWithCurrManager        Age  \
# Attrition
# No                        2.243265              4.377143  37.542041
# Yes                       1.961702              2.863830  33.621277
#
#            DistanceFromHome
# Attrition
# No                 8.902041
# Yes               10.582979

# %%
# or
df.groupby("Attrition").mean()
# Out:
#            HourlyRate  JobLevel  JobSatisfaction   MonthlyRate  \
# Attrition
# No          65.977959  2.146939         2.780408  14254.193469
# Yes         65.582979  1.642553         2.463830  14535.455319
#
#            NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# Attrition
# No                   2.648980          15.242449          11.862857
# Yes                  2.944681          15.093617           8.280851
#
#            WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# Attrition
# No                2.782041        7.388571            4.497959
# Yes               2.659574        5.153191            2.919149
#
#            YearsSinceLastPromotion  YearsWithCurrManager        Age  \
# Attrition
# No                        2.243265              4.377143  37.542041
# Yes                       1.961702              2.863830  33.621277
#
#            DistanceFromHome
# Attrition
# No                 8.902041
# Yes               10.582979

# %% [markdown]
# ### Q16. Check the details of 5 employees who have spent maximum years in the company

# %%
df.sort_values(by = 'YearsAtCompany', ascending = 'False').head(5)
# Out:
#          BusinessTravel              Department  HourlyRate  JobLevel  \
# 727          Non-Travel  Research & Development          73       1.0
# 936   Travel_Frequently  Research & Development          83       5.0
# 1237      Travel_Rarely                   Sales          34       2.0
# 1074      Travel_Rarely  Research & Development          69       2.0
# 1287      Travel_Rarely  Research & Development          95       2.0
#
#                         JobRole  JobSatisfaction  MonthlyRate  \
# 727          Research Scientist                4        13493
# 936                     Manager                2        13035
# 1237            Sales Executive                2        12147
# 1074  Healthcare Representative                3        22049
# 1287  Healthcare Representative                1         5696
#
#       NumCompaniesWorked OverTime  PercentSalaryHike       ...         \
# 727                    1       No                 15       ...
# 936                    3       No                 22       ...
# 1237                   6       No                 15       ...
# 1074                   2      Yes                 17       ...
# 1287                   5       No                 18       ...
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 727                0                   0                        0
# 936                0                   0                        0
# 1237               0                   0                        0
# 1074               0                   0                        0
# 1287               0                   0                        0
#
#       YearsWithCurrManager  Attrition  Age EducationField  Gender  \
# 727                      0         No   18  Life Sciences    Male
# 936                      0         No   45        Medical  Female
# 1237                     0        Yes   32  Life Sciences    Male
# 1074                     0         No   33  Life Sciences    Male
# 1287                     0         No   42        Medical    Male
#
#      MaritalStatus DistanceFromHome
# 727         Single                5
# 936         Single               25
# 1237        Single                1
# 1074        Single                8
# 1287       Married               13
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Q17.  Find out the minimum "Percentage Salary Hike" the company has offered?

# %%
df['PercentSalaryHike'].min()
# Out:
# 11

# %%
# or
df.PercentSalaryHike.min()
# Out:
# 11

# %% [markdown]
# ### Q18. What is the maximum Total Working Years of an employee?

# %%
df['YearsAtCompany'].max()
# Out:
# 40

# %% [markdown]
# ### Q19. What percentage of employees stay in the company given they have spend more than 7 years with the current manager?

# %%
df[df['YearsWithCurrManager'] > 7]['Attrition'].value_counts(normalize = 'True')
# Out:
# No     0.918519
# Yes    0.081481
# Name: Attrition, dtype: float64

# %% [markdown]
# ### Q20.  What percentage of employees lives >10 miles from the company?

# %%
df[df['DistanceFromHome'] > 10]['DistanceFromHome'].count()
# Out:
# 439

# %%
df.shape[0]
# Out:
# 1460

# %%
(df[df['DistanceFromHome'] > 10]['DistanceFromHome'].count()/df.shape[0])*100
# Out:
# 30.068493150684933

# %% [markdown]
# ### Q21. Create a copy of the dataset , remove the "Attrition" variable from the new dataset and check the shape of the dataset

# %%
df_copy = df.copy()

# %%
df_copy.drop("Attrition", axis = 1, inplace = True)
df_copy.shape
# Out:
# (1460, 21)

# %% [markdown]
# # END
